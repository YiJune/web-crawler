# %%
from bs4 import BeautifulSoup
path="C:\\Users\\YiJune\\PY\\web (2).html"
with open (path,"r",encoding="utf-8") as f:#W:寫入 R:讀取 encoding:讀取編碼
    soup=BeautifulSoup(f.read(),'html') #轉換成Beautifulsoup格式  f.read:讀取
print(soup)
# Out:
# <html>
# <head>
# <title>網頁標題</title>
# </head><body><a href="https://www.1111.com.tw/search/job?ks=%E5%A4%A7%E6%95%B8%E6%93%9A">這是一個連結</a>
# <a> 第2行 </a>
# <a> 第3行 </a>
# <h1 class="abc" href="https://ithelp.ithome.com.tw/storage/image/logo.svg">abc</h1>
# <a> 第4行 </a>
# <a> 第5行 </a>
# <p>這是<strong>一個</strong>段落</p>
# <p>你看得見我</p>
# <p hidden="">你看不見我</p>
# <h1 class="job">職缺：<h2>大數據工程師</h2> </h1>
# </body></html>

# %%
from bs4 import BeautifulSoup
path="C:\\Users\\YiJune\\PY\\web (2).html"
with open (path,"r",encoding="utf-8") as f:#W:寫入 R:讀取 encoding:讀取編碼
    soup=BeautifulSoup(f.read(),'html') #轉換成Beautifulsoup格式  f.read:讀取
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    網頁標題
#   </title>
#  </head>
#  <body>
#   <a href="https://www.1111.com.tw/search/job?ks=%E5%A4%A7%E6%95%B8%E6%93%9A">
#    這是一個連結
#   </a>
#   <a>
#    第2行
#   </a>
#   <a>
#    第3行
#   </a>
#   <h1 class="abc" href="https://ithelp.ithome.com.tw/storage/image/logo.svg">
#    abc
#   </h1>
#   <a>
#    第4行
#   </a>
#   <a>
#    第5行
#   </a>
#   <p>
#    這是
#    <strong>
#     一個
#    </strong>
#    段落
#   </p>
#   <p>
#    你看得見我
#   </p>
#   <p hidden="">
#    你看不見我
#   </p>
#   <h1 class="job">
#    職缺：
#    <h2>
#     大數據工程師
#    </h2>
#   </h1>
#  </body>
# </html>

# %%
print(soup.head.title.text) #text:純文字
# Out:
# 網頁標題

# %%
print(soup.find_all("a")) #find_all 找全部
# Out:
# [<a href="https://www.1111.com.tw/search/job?ks=%E5%A4%A7%E6%95%B8%E6%93%9A">這是一個連結</a>, <a> 第2行 </a>, <a> 第3行 </a>, <a> 第4行 </a>, <a> 第5行 </a>]

# %%
print(soup.find("h1",class_="abc")) #find:找h1的class
# Out:
# <h1 class="abc" href="https://ithelp.ithome.com.tw/storage/image/logo.svg">abc</h1>

# %%
print(soup.select(".abc"))
# Out:
# [<h1 class="abc" href="https://ithelp.ithome.com.tw/storage/image/logo.svg">abc</h1>]

# %%
print(soup.select("h1[class=job]"))
# Out:
# [<h1 class="job">職缺：<h2>大數據工程師</h2> </h1>]

# %%
print(soup("a"))
# Out:
# [<a href="https://www.1111.com.tw/search/job?ks=%E5%A4%A7%E6%95%B8%E6%93%9A">這是一個連結</a>, <a> 第2行 </a>, <a> 第3行 </a>, <a> 第4行 </a>, <a> 第5行 </a>]

# %%
print(soup.h2.text)
# Out:
# 大數據工程師

# %%
import requests
from bs4 import BeautifulSoup
res=requests.get("https://www.104.com.tw/jobs/search/?keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&order=1&jobsource=2018indexpoc&ro=0")
soup=BeautifulSoup(res.text, "html.parser") 
# print(soup.prettify())
print(soup.article["data-cust-name"]) #到目標網站找尋範圍tag名稱   data-cust-name:選取KEY
print()
# Out:
# 台灣壽司郎股份有限公司

# %%
import requests
from bs4 import BeautifulSoup
res=requests.get("https://www.104.com.tw/jobs/search/?keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&order=1&jobsource=2018indexpoc&ro=0")
soup=BeautifulSoup(res.text, "html.parser") 
# print(soup.prettify())
print(soup.article("li")[2].text) #到目網站找尋範圍tag名稱
# Out:
# 桃園市蘆竹區

# %%
import requests
from bs4 import BeautifulSoup
res=requests.get("https://www.104.com.tw/jobs/search/?keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&order=1&jobsource=2018indexpoc&ro=0")
soup=BeautifulSoup(res.text) 
# print(soup.prettify())
print(soup.article("a")[0].text) #到目網站找尋範圍tag名稱
# Out:
# 【日商 壽司郎】桃園台茂店-兼職人員（★時薪190元起）歡迎二度就業、新住民、復職同仁、寒暑假打工

# %%
import requests
from bs4 import BeautifulSoup
res=requests.get("https://www.104.com.tw/jobs/search/?keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&order=1&jobsource=2018indexpoc&ro=0")
soup=BeautifulSoup(res.text) 
# print(soup.prettify())
print(soup.article("a")[1].text) #到目網站找尋範圍tag名稱
# Out:
# 台灣壽司郎股份有限公司

# %%
import requests
from bs4 import BeautifulSoup
res=requests.get("https://www.104.com.tw/jobs/search/?keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&order=1&jobsource=2018indexpoc&ro=0")
soup=BeautifulSoup(res.text, "html.parser") 
# print(soup.prettify())
print(soup.article("span")[1].text) #到目網站找尋範圍tag名稱
# Out:
# 儲存

# %%
import requests
from bs4 import BeautifulSoup
res=requests.get("https://www.104.com.tw/jobs/search/?keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&order=1&jobsource=2018indexpoc&ro=0")
soup=BeautifulSoup(res.text, "html.parser")
# print(soup.prettify())
print("https:"+soup.article("a")[0]["href"]) #到目網站找尋範圍tag名稱
# Out:
# https://www.104.com.tw/job/7rtss?jobsource=hotjob_chr

# %%
num = 0
for job in soup.find_all("article")[:-2] : #[:-2] 直接刪掉2個有問題的
    num+=1
   
    if num ==job:
        break
    print(job["data-cust-name" ])
# Out:
# 台灣壽司郎股份有限公司
# 摩斯漢堡_安心食品服務股份有限公司
# 杏豐實業股份有限公司
# 台北神策諮詢顧問有限公司
# 昱峰智能大數據科技股份有限公司
# 典通股份有限公司
# 典通股份有限公司
# 動力安全資訊股份有限公司
# 台灣恩悌悌數據股份有限公司
# 典通股份有限公司
# 台北神策諮詢顧問有限公司
# 現觀科技股份有限公司
# 大數據股份有限公司
# 博揚機械有限公司
# 典通股份有限公司
# 台北神策諮詢顧問有限公司
# 群益金鼎證券股份有限公司
# 欣興電子股份有限公司
# 大拇哥證券投資顧問股份有限公司
# 群健科技股份有限公司
# 典通股份有限公司
# 中嘉數位股份有限公司

# %%
num = 0
for job in soup.find_all("article",class_="b-block--top-bord job-list-item b-clearfix js-job-item") :
    num+=1
   
    if num ==job:
        break
    print(job["data-cust-name" ])
# Out:
# 杏豐實業股份有限公司
# 台北神策諮詢顧問有限公司
# 昱峰智能大數據科技股份有限公司
# 典通股份有限公司
# 典通股份有限公司
# 動力安全資訊股份有限公司
# 台灣恩悌悌數據股份有限公司
# 典通股份有限公司
# 台北神策諮詢顧問有限公司
# 現觀科技股份有限公司
# 大數據股份有限公司
# 博揚機械有限公司
# 典通股份有限公司
# 台北神策諮詢顧問有限公司
# 群益金鼎證券股份有限公司
# 欣興電子股份有限公司
# 大拇哥證券投資顧問股份有限公司
# 群健科技股份有限公司
# 典通股份有限公司
# 中嘉數位股份有限公司

# %%
page=1
while soup.article("a") !=[]:
    for job in soup.find_all("article",class_="b-block--top-bord job-list-item b-clearfix js-job-item") :
        print(job["data-cust-name" ])
        print(job.find("a",class_="js-job-link").text)
        print("https:"+job("a")[0]["href"])
        print(job("li")[2].text) 
        print(".......................................................................")
    page+=1
    res=requests.get("https://www.104.com.tw/jobs/search/?ro=0&kwop=7&keyword=%E7%88%AC%E8%9F%B2&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=15&asc=0&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1&page="+str(page))
    soup=BeautifulSoup(res.text, "html.parser")
# Out:
# 杏豐實業股份有限公司
# 大數據分析
# https://www.104.com.tw/job/7qr2q?jobsource=jolist_c_relevance
# 藥品／化妝品及清潔用品零售業
# .......................................................................
# 台北神策諮詢顧問有限公司
# 大數據產品交付諮詢實習生
# https://www.104.com.tw/job/7wpbv?jobsource=jolist_c_relevance
# 電子通訊／電腦週邊批發業
# .......................................................................
# 昱峰智能大數據科技股份有限公司
# AI 大數據科學家
# https://www.104.com.tw/job/5x0ln?jobsource=jolist_c_relevance
# 電腦軟體服務業
# .......................................................................
# 典通股份有限公司
# 大數據部門商業分析師
# https://www.104.com.tw/job/7k72g?jobsource=jolist_c_relevance
# 工商顧問服務業
# .......................................................................
# 典通股份有限公司
# 大數據部門研究員
# https://www.104.com.tw/job/7k69c?jobsource=jolist_c_relevance
# 工商顧問服務業
# .......................................................................
# 動力安全資訊股份有限公司
# [DI] 大數據 工程師
# https://www.104.com.tw/job/4jnp8?jobsource=jolist_c_relevance
# 電腦系統整合服務業
# ...

# %%
import openpyxl

wb=openpyxl.Workbook()
ws=wb.active

ws['A1']='直缺名稱'
ws['B1']='直缺連結'
ws['C1']='公司名稱'
ws['D1']='工作待遇'
ws['E1']='薪資待遇'
ws.append([1,2,3,4,5])


wb.save("one.xlse")

# %%
import requests
from bs4 import BeautifulSoup
from openpyxl import Workbook

res=requests.get("https://www.104.com.tw/jobs/search/?keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&order=1&jobsource=2018indexpoc&ro=0")
soup=BeautifulSoup(res.text, "html.parser") 
# 創建 Excel 工作簿
wb = Workbook()
ws = wb.active

page = 1

while soup.find_all("article", class_="b-block--top-bord job-list-item b-clearfix js-job-item")!=[]:
    for job in soup.find_all("article", class_="b-block--top-bord job-list-item b-clearfix js-job-item"):
        cust_name = job["data-cust-name"]
        job_title = job.find("a", class_="js-job-link").text
        job_link = "https:" + job("a")[0]["href"]
        job_info = job("li")[2].text

        # 將數據寫入 Excel 工作表
        ws.append([cust_name, job_title, job_link, job_info])

    page += 1
    res = requests.get("https://www.104.com.tw/jobs/search/?ro=0&kwop=7&keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=15&asc=0&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1&page=" + str(page))
    soup = BeautifulSoup(res.text, "html.parser")

    # 儲存 Excel 檔案
    wb.save("jobs2.xlsx")
# Out:
# KeyboardInterrupt

# %%
import requests
from bs4 import BeautifulSoup
res=requests.get("https://news.google.com/topics/CAAqKggKIiRDQkFTRlFvSUwyMHZNRFZxYUdjU0JYcG9MVlJYR2dKVVZ5Z0FQAQ?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant")
soup=BeautifulSoup(res.text, 'html.parser') 
# x=soup.find_all("article",class_="UwIKyb")[0].h4.text
# print(x)
num=0
for news in soup.find_all("article",class_="UwIKyb"):
    num+=1
   
    if num ==news:
        break
    print(num,".",news.h4.text)
    print("https://news.google.com/"+news.a["href"])
# Out:
# 1 . 詐騙集團不只養陳歐珀 藍營市議員驚爆：他是全家被包養！
# https://news.google.com/....?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant
# 2 . 陳歐珀爆與im.B詐團來往 侯友宜重砲轟賴清德：你不用負責嗎
# https://news.google.com/./articles/CBMiPWh0dHBzOi8vd3d3LmNoaW5hdGltZXMuY29tL3JlYWx0aW1lbmV3cy8yMDIzMDUyMjAwMTgxNy0yNjA0MDfSAUFodHRwczovL3d3dy5jaGluYXRpbWVzLmNvbS9hbXAvcmVhbHRpbWVuZXdzLzIwMjMwNTIyMDAxODE3LTI2MDQwNw?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant
# 3 . 陳歐珀捲吸金案 鄭文燦籲說清楚：任何政治人物都不會幫詐團背書│TVBS新聞網
# https://news.google.com/./articles/CBMiKWh0dHBzOi8vbmV3cy50dmJzLmNvbS50dy9wb2xpdGljcy8yMTI5NjIz0gEtaHR0cHM6Ly9uZXdzLnR2YnMuY29tLnR3L2FtcC9wb2xpdGljcy8yMTI5NjIz?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant
# 4 . 慘遭封殺！疑台大經濟系校友制裁「禁止取得實習與正職機會」
# https://news.google.com/./articles/CBMiNmh0dHBzOi8vbmV3cy5sdG4uY29tLnR3L25ld3MvbGlmZS9icmVha2luZ25ld3MvNDMwODgyNNIBOmh0dHBzOi8vbmV3cy5sdG4uY29tLnR3L2FtcC9uZXdzL2xpZmUvYnJlYWtpbmduZXdzLzQzMDg4MjQ?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant
# 5 . 「母單要結紮」會長候選人稱譁眾 律師看不到誠意：等社會教他
# ...

# %%
import requests
from bs4 import BeautifulSoup
from openpyxl import Workbook

# 創建 Excel 工作簿
wb = Workbook()
ws = wb.active
res=requests.get("https://news.google.com/topics/CAAqKggKIiRDQkFTRlFvSUwyMHZNRFZxYUdjU0JYcG9MVlJYR2dKVVZ5Z0FQAQ?hl=zh-TW&gl=TW&ceid=TW%3Azh-Hant")
soup=BeautifulSoup(res.text, 'html.parser') 
# x=soup.find_all("article",class_="UwIKyb")[0].h4.text
# print(x)
num=0
for news in soup.find_all("article",class_="UwIKyb"):
    num+=1
   
    if num ==news:
        break
    news_title=str(num)+str(".")+news.h4.text
    href="https://news.google.com/"+news.a["href"]
    ws.append([news_title,href])

#     wb.save("news.xlsx")
# Out:
# KeyboardInterrupt

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get("https://ifoodie.tw/")
soup = BeautifulSoup(res.text,'html')
next_url = soup.find_all("div",class_="jsx-1638812939 category-block-item-outer")[0].a["href"]
print(f'https://ifoodie.tw{next_url}')
# Out:
# https://ifoodie.tw/explore/台北市/list/%E9%8D%8B%E9%A1%9E
